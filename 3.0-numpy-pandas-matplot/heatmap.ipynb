# %%
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt
y_true = ["cat", "ant", "cat", "cat", "ant", "bird"]
y_pred = ["ant", "ant", "cat", "cat", "ant", "cat"]
labels={"ant":0, "bird":1, "cat":2}
n = len(labels)
cm = np.zeros((n, n))

for t, p in zip(y_true, y_pred):
    i, j = labels[t], labels[p]
    cm[i, j] += 1
print(cm)
fig, ax = plt.subplots(figsize=(10,4))
heatmap = sn.heatmap(cm,  cmap="YlGnBu", annot=True,fmt='2g', xticklabels=labels.keys(), yticklabels=labels.keys(), ax=ax)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# [[2. 0. 0.]
#  [0. 0. 1.]
#  [1. 0. 2.]]

# %%
# !conda list |grep seaborn
# Out:
# WARNING: The conda.compat module is deprecated and will be removed in a future release.
# seaborn                   0.8.1                    py37_0

# %%
import numpy as np; np.random.seed(0)
import seaborn as sns; sns.set()
uniform_data = np.random.rand(10, 10)

sn.heatmap(data = uniform_data)

plt.show()
